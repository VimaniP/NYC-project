# %% [markdown]
# # Phase 1 Project
#
# ## Introduction
#
# Congratulations on completing phase 1! In this notebook, you will complete a final project that applies your python and visualization skills to real word business data.
#
# ## Objectives
# In this project, you will...
# - Read in data that has been stored as a `json` file.
# - Describe how the data is structured.
# - Use Python to filter a nested data structure
# - Define python functions
# - Calculate descriptive statistics
# - Visualize data via matplotlib
#
#
# # Task: Compare New York Pizza Restaurants with Above Average and Below Average Ratings
# ![Pizza gif](https://media.giphy.com/media/eK1eFdpj5kMWqZ9bLJ/giphy.gif?cid=ecf05e47rkbp48nwz3za6dloo8xfwzueu0rx2vklguo7xyhu&rid=giphy.gif&ct=g)
#
# ## Business Understanding
#
# A client at your analytics firm is considering opening a pizza restaurant in New York City.
#
# They have asked you to develop a business intelligence report to fact check the following claims:
# 1. Your client wants to ensure they have an above average Yelp rating. They have previously owned restuarants in other cities, where a `3` was the average. They would like to know if that holds true in New York City.
# 1. Your client has noticed that restaurants on yelp with a high review count seem to be quite successful. They have decided to focus on maximizing their review count which they believe will allow them to have an above average overall review.
# 1. After looking at a few restaurants on Yelp, your client believes that most above average restaurants have a price point of `$$`. They are considering increasing their prices from `$` to `$$` to match the majority of above average restaurants, and would like you to find the most common price point for above average restaurants in New York City.
# 1. In terms of location they have been told that above average restaurants are usually further east and below average are usually further west, but that the biggest difference is whether the restaurant is on the north or south side. They would like you to determine if the data supports this claim.
# 1. They believe that the `10012` zipcode in New York City is the best place to open a restaurant. They wish to open a restaurant in close proximity to other highly rated restaurants, and they believe `10012` has the most in NYC.
#
#
#
# The primary purpose of this analysis is _descriptive_, meaning your analysis should report calculated statistics such as `counts` and `mean`, and should be focused on providing a simple, factual, understanding of the data.
#
#
# ## Data Understanding
#
# You have been provided a Yelp dataset containing information about restaurants in New York City. The data is named `pizza_businesses.json` and is stored in the current working directory. You will need to load in this dataset, inspect how the data is structured, and use the provided information to fact check your client's claims.

# %% [markdown]
# ## Load the data
#
# A dataset containing information about New York pizza restaurants is stored in this notebook's repository with the name `pizza_businesses.json`.
#
# In the cell below, load the json data into a python dictionary.

# %%
# Import the json python package
# YOUR CODE HERE
import json
# Load in the data
# YOUR CODE HERE
with open('pizza_businesses.json') as f:
    data_pizza = json.load(f)

# %% [markdown]
# ## Describe the data
#
# Now that you've loaded in the dataset, the structure of the data should be inspected.
#
# In the cell below, evaluate
# - The datatype of the overall dataset
# - The datatype of a single observation
# - The number of observations, and then
# - Isolate the first observation in the dataset

# %%
# Replace None with your code!
  
# Find the datatype for the overall dataset
dataset_type = type(data_pizza)
# Isolate the first observation
first_observation = data_pizza[0] 
# Find the datatype for the first observation
observation_type = type(first_observation)
# How many observations are there
num_observations = len(data_pizza)

# %% [markdown]
# Run this following cell unchanged to print out descriptive information for the dataset!

# %%
from pprint import pprint

print(f'The dataset is a \033[1m{dataset_type}\033[0m')
print(f'The observations are a \033[1m{observation_type}\033[0m',)
print(f'There are \033[1m{num_observations} observations.\033[0m')
print('\033[1m\nThe first observation:\033[0m')
print('==========================================')
pprint(first_observation)
print('==========================================')
# Out:
# The dataset is a <class 'list'>
# The observations are a <class 'dict'>
# There are 1000 observations.
#
# The first observation:
# ==========================================
# {'latitude': 40.72308755605564,
#  'location': {'address1': '27 Prince St',
#               'address2': None,
#               'address3': '',
#               'city': 'New York',
#               'country': 'US',
#               'display_address': ['27 Prince St', 'New York, NY 10012'],
#               'state': 'NY',
#               'zip_code': '10012'},
#  'longitude': -73.99453001177575,
#  'name': 'Prince Street Pizza',
#  'phone': '+12129664100',
#  'price': '\\$',
#  'rating': 4.5,
#  'review_count': 3976,
#  'transactions': ['delivery', 'pickup']}
# ==========================================

# %% [markdown]
# ## Find the possible rating options.
#
# In the cell below, create a variable called `rating_options` that has a [set datatype](https://realpython.com/python-sets/), and is a unique collection of the possible ratings a restaurant can recieve.

# %%
# Create the `rating_options` variable
rating_options = set()


# Loop over all of the observations in the dataset
for index in range(len(data_pizza)):
    data_dict =data_pizza[index]
    
        
    # Isolate the rating for the restaurant
    # YOUR CODE HERE
    rating = data_dict['rating']
    if rating not in rating_options:
        
    # Add the rating to 
    # the `rating_options` variable
    # YOUR CODE HERE
        rating_options.add(data_dict['rating']) 
    
rating_options
# Out:
# {1.0, 2.0, 2.5, 3.0, 3.5, 4.0, 4.5, 5.0}

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(rating_options) == set
assert len(rating_options) == 8
assert list(rating_options)[0] != list(rating_options)[1]

# %% [markdown]
# ## Plot the distribution for ratings
#
# Now that you know what rating options are available, in the cell below plot a histogram showing the distribution of ratings.

# %%
# Import matplotlib's pyplot module

# Create an empty list.
# We will store all ratings in this list
ratings = []

# Loop over every restaurant in the dataset
# YOUR CODE HERE
for index in range(len(data_pizza)):
    data_dict =data_pizza[index]

    # Isolate the rating
    # YOUR CODE HERE
    # Append the rating to the `ratings` list
    # YOUR CODE HERE
    rating = data_dict['rating']
    ratings.append(data_dict['rating']) 
# Create a matplotlib subplot
# YOUR CODE HERE
# Create the plot
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots()


# Plot a histogram of the ratings list
# YOUR CODE HERE
# Create the plot


# Graph the distribution of X
ax.hist(ratings)

# Set title
ax.set_title("Histogram in Matplotlib")
# Out:
# Text(0.5, 1.0, 'Histogram in Matplotlib')

# %% [markdown]
# **Interpret the ratings histogram. How does the visualization relate to your client's claims?**

# %% [markdown]
# Client claims that the previous Average rating was 3. According visualization highest avrage is 5. And there are 40 restrurants for 5 rating. There are 260 resturants for 4.5 ratings . There are 440 resturaants for 4 ratings .  There are 190 resturants for 3.5 rating. There are about 30 resturants for 3 ratings. There are abut 10 with 2.5 ratings. No retrurants with 1.5 and one resturant with 1 ratings. Number of returant is a rough figure as per the Histogram

# %% [markdown]
# ## Isolate the restaurants with an above average rating
#
# Now that you have an understanding for what is an average rating, next you will isolate restaurants with above average and below average ratings so you can compare them.
#
# In the cell below, filter out all restaurants that do not have a rating of at least `4.5`.

# %%
import collections
# Create an empty list
# You will store restaurants in this list
above_average = []
 

# Loop over the dataset
# YOUR CODE HERE
for index in range(len(data_pizza)):
    data_dict =data_pizza[index]
    
    # Isolate the rating
    # YOUR CODE HERE
        
    # Check if the rating is at least 4.5
    # YOUR CODE HERE
        # If the rating is at least 4.5
        # Add the restaurant to the list
        # YOUR CODE HERE
    if  data_dict['rating'] >= 4.5:
        
        above_average.append(data_dict.copy())     
         
above_average
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 3976,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129664100',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2354,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17185966700',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': 'Rubirosa',
#   'review_count': 2438,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129650500',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 596,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery'],
#   'phone': '+17185990002',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 154,
#   'rating': 5.0,
#   'price': '\\$\\$',
#   'location': {'address1': '279 71st St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['279 71st St', 'Brooklyn, NY 11209']},
#   'transactions': ['pickup'],
#   'phone': '+17182387100',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': "Mimi's Pizza",
#   'review_count': 67,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '217 E 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 E 86th St', 'New York, NY 10028']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468612518',
#   'latitude': 40.778638,
#   'longitude': -73.952895},
#  {'name': "Paulie Gee's",
#   'review_count': 1285,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery'],
#   'phone': '+13479873747',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': 'Brunetti Pizza',
#   'review_count': 310,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '626 Hudson St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['626 Hudson St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122555699',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': 'Koronet Pizza',
#   'review_count': 42,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '1110 Lexington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1110 Lexington Ave', 'New York, NY 10075']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16467670424',
#   'latitude': 40.77408,
#   'longitude': -73.95969},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 255,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '326 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery'],
#   'phone': '+17187832430',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': 'Olio e Piú',
#   'review_count': 2748,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York City',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122436546',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': 'Gelso & Grand',
#   'review_count': 1080,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '186 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Grand St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122261600',
#   'latitude': 40.7194089547259,
#   'longitude': -73.9973777877722},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 562,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '450 Dean St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186222268',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': 'My Pie',
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '166 West 72nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['166 West 72nd St', 'New York, NY 10023']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127877200',
#   'latitude': 40.77823,
#   'longitude': -73.98117},
#  {'name': 'Village Square Pizza',
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '147 Ave A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['147 Ave A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19176757709',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Unregular Pizza',
#   'review_count': 62,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '135 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['135 4th Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466094699',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': 'Piz-zetta',
#   'review_count': 303,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '90 Livingston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184227878',
#   'latitude': 40.6912834070746,
#   'longitude': -73.9906029201042},
#  {'name': 'Norma',
#   'review_count': 476,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '438 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128890600',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': 'NYC Pizza Kitchen',
#   'review_count': 4,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '390 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['390 3rd Ave', 'New York, NY 10016']},
#   'transactions': [],
#   'phone': '+12127299497',
#   'latitude': 40.741947306680636,
#   'longitude': -73.98095156997442},
#  {'name': 'Bellucci Pizza',
#   'review_count': 117,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '29-04 30th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11102',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['29-04 30th Ave', 'Astoria, NY 11102']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17189711074',
#   'latitude': 40.76772937223715,
#   'longitude': -73.9234633428848},
#  {'name': 'Song E Napule',
#   'review_count': 556,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '146 W Houston St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['146 W Houston St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125331242',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 212,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '345 E 12th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['345 E 12th St', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16469834007',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 154,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13479161062',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 797,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '690 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123171850',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Mario’s Pizza',
#   'review_count': 11,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '940 Manhattan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['940 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183492700',
#   'latitude': 40.731392,
#   'longitude': -73.954136},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 657,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '298 Atlantic Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17188528758',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Baker's Pizza",
#   'review_count': 238,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '201 Avenue A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 Avenue A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127777477',
#   'latitude': 40.72942181645356,
#   'longitude': -73.98127671518847},
#  {'name': "Zazzy's Pizza",
#   'review_count': 39,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '75 Greenwich Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['75 Greenwich Ave', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125420226',
#   'latitude': 40.736699,
#   'longitude': -74.001447},
#  {'name': 'Upside Pizza',
#   'review_count': 27,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '51 Spring St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['51 Spring St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.722115,
#   'longitude': -73.996407},
#  {'name': 'Barano',
#   'review_count': 281,
#   'rating': 4.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '26 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 Broadway', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13479874500',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': 'Salsa Pizzeria',
#   'review_count': 7,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '40 Clifford Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['40 Clifford Pl', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13475424680',
#   'latitude': 40.7269007,
#   'longitude': -73.9554019},
#  {'name': 'Adoro Lei',
#   'review_count': 316,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '287 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['287 Hudson St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466665096',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 187,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '90-92 Gansevoort St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124622703',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Nolita Pizza',
#   'review_count': 91,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '68 Kenmare St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468959131',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': "Manero's Pizza",
#   'review_count': 59,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '113 Mulberry St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['113 Mulberry St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.717593,
#   'longitude': -73.998396},
#  {'name': "Ace's Pizza",
#   'review_count': 50,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery'],
#   'phone': '+13477254366',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': 'Rome To Brooklyn Pizza',
#   'review_count': 84,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'New York, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182693239',
#   'latitude': 40.71187,
#   'longitude': -73.94283},
#  {'name': 'Burrata Pizza',
#   'review_count': 4,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '221 Ave A',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 Ave A', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.7302,
#   'longitude': -73.98069},
#  {'name': 'Rosemary’s',
#   'review_count': 65,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '350 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['350 1st Ave', 'New York, NY 10010']},
#   'transactions': [],
#   'phone': '+16468685335',
#   'latitude': 40.73512,
#   'longitude': -73.97965},
#  {'name': "Nonna's Pizza",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '12 W 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['12 W 18th St', 'New York, NY 10011']},
#   'transactions': ['delivery'],
#   'phone': '+12122060500',
#   'latitude': 40.73891,
#   'longitude': -73.99298},
#  {'name': 'Champion Pizza',
#   'review_count': 367,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '17 Cleveland Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122263777',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': "Giuseppina's",
#   'review_count': 326,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '691 6th Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['691 6th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup'],
#   'phone': '+17184995052',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 226,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '989 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['989 1st Ave', 'New York, NY 10022']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128888816',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': 'Lazzaro',
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '110 Trinity Place',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Trinity Place', 'New York, NY 10006']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127964499',
#   'latitude': 40.70948,
#   'longitude': -74.012},
#  {'name': 'Coco Pazzeria',
#   'review_count': 16,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '307 Spring St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['307 Spring St', 'New York, NY 10013']},
#   'transactions': ['delivery'],
#   'phone': '+16468501003',
#   'latitude': 40.726166,
#   'longitude': -74.008441},
#  {'name': "Proto's Pizza",
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '50 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['50 2nd Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124324044',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Ops',
#   'review_count': 153,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '346 Himrod St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['346 Himrod St', 'Brooklyn, NY 11237']},
#   'transactions': ['delivery'],
#   'phone': '+17183864009',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 562,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '9824 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9824 4th Ave', 'Brooklyn, NY 11209']},
#   'transactions': ['delivery'],
#   'phone': '+13475174868',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 149,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '567 Vanderbilt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183999000',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '190 Cypress Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['190 Cypress Ave', 'Brooklyn, NY 11237']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184561833',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': "Rosa's Pizza",
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '374 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189632378',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': "Luigi's Pizza",
#   'review_count': 357,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '686 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['686 5th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184993857',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': 'Uncle Frankie’s Brick Oven Pizza',
#   'review_count': 49,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '3007 Fort Hamilton Pkwy',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11218',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3007 Fort Hamilton Pkwy', 'Brooklyn, NY 11218']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17188543462',
#   'latitude': 40.64852,
#   'longitude': -73.9787},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 453,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '469 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['469 5th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187687244',
#   'latitude': 40.668221,
#   'longitude': -73.986936},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 289,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '16 E 41st St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['16 E 41st St', 'New York, NY 10017']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467915690',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': 'Roebling Pizza',
#   'review_count': 120,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '326 Roebling St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['326 Roebling St', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187825042',
#   'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639},
#  {'name': 'Village Square Pizza - West Village',
#   'review_count': 36,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '118 Christopher St W',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['118 Christopher St W', 'New York, NY 10014']},
#   'transactions': ['delivery'],
#   'phone': '+16466924028',
#   'latitude': 40.733052,
#   'longitude': -74.005461},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '25-19 40th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Long Island City',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['25-19 40th Ave', 'Long Island City, NY 11101']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184721932',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '14 Newkirk Plz',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11226',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14 Newkirk Plz', 'Brooklyn, NY 11226']},
#   'transactions': ['delivery'],
#   'phone': '+17188591501',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1164,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '370 W 51st St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['370 W 51st St', 'New York, NY 10019']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16466797225',
#   'latitude': 40.76394,
#   'longitude': -73.9883399},
#  {'name': "Uncle Sam's Pizza",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '17 Clinton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 Clinton St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468761111',
#   'latitude': 40.720827,
#   'longitude': -73.984367},
#  {'name': "Roberta's",
#   'review_count': 3,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '196 Stanton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['196 Stanton St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '',
#   'latitude': 40.71995520720623,
#   'longitude': -73.98304455197378},
#  {'name': 'Double Zero',
#   'review_count': 559,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '65 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['65 2nd Ave', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127771608',
#   'latitude': 40.7261288,
#   'longitude': -73.9896645},
#  {'name': 'Old Fashioned Pizza',
#   'review_count': 27,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '244 E 13th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['244 E 13th St', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12125051781',
#   'latitude': 40.73182,
#   'longitude': -73.98607},
#  {'name': 'Pizza Moto',
#   'review_count': 210,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '338 Hamilton Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['338 Hamilton Ave', 'Brooklyn, NY 11231']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17188346686',
#   'latitude': 40.6746224,
#   'longitude': -74.0007999},
#  {'name': 'Il Mattone',
#   'review_count': 92,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '49 Beach St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['49 Beach St', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16469644623',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Slice Joint',
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '115 Delancey St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['115 Delancey St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13324560129',
#   'latitude': 40.71827,
#   'longitude': -73.98806},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 41,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '1827 2nd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1827 2nd Ave', 'New York, NY 10128']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+19176756867',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': 'Donna Margherita',
#   'review_count': 96,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1304 2nd Ave',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10065',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1304 2nd Ave', 'Ste A', 'New York, NY 10065']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127721169',
#   'latitude': 40.76652,
#   'longitude': -73.9598},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 324,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '443 Knickerbocker Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184559664',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': "Pop's Pizzas",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '301 West 57th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['301 West 57th St', 'New York, NY 10019']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127848863',
#   'latitude': 40.767086,
#   'longitude': -73.983033},
#  {'name': "Philomena's",
#   'review_count': 128,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '41-16 Queens Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Sunnyside',
#    'zip_code': '11104',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['41-16 Queens Blvd', 'Sunnyside, NY 11104']},
#   'transactions': ['delivery'],
#   'phone': '+17182551778',
#   'latitude': 40.7432,
#   'longitude': -73.92275},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 289,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '4407 Queens Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Sunnyside',
#    'zip_code': '11104',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4407 Queens Blvd', 'Sunnyside, NY 11104']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186852086',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': 'Death By Pizza',
#   'review_count': 28,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '240 W 14th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['240 W 14th St', 'New York, NY 10011']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127319924',
#   'latitude': 40.739176881019205,
#   'longitude': -74.00178874784991},
#  {'name': 'Tailfeather',
#   'review_count': 22,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '581 Myrtle Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['581 Myrtle Ave', 'New York, NY 11205']},
#   'transactions': ['delivery'],
#   'phone': '+13472405915',
#   'latitude': 40.69415,
#   'longitude': -73.96089},
#  {'name': 'Pizza Collective',
#   'review_count': 63,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '2060 Broadway',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2060 Broadway', 'New York, NY 10023']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16466930949',
#   'latitude': 40.77795,
#   'longitude': -73.98155},
#  {'name': 'Rivington Pizza',
#   'review_count': 18,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '170 Rivington St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['170 Rivington St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16463603343',
#   'latitude': 40.719146,
#   'longitude': -73.984627},
#  {'name': 'Forcella Fried Pizza',
#   'review_count': 57,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '445 Albee square W',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['445 Albee square W', 'New York, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19293794085',
#   'latitude': 40.69088,
#   'longitude': -73.982868},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 29,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '383 Canal St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['383 Canal St', 'New York, NY 10013']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12129661110',
#   'latitude': 40.7216890942271,
#   'longitude': -74.0046280995011},
#  {'name': 'Marinara Pizza',
#   'review_count': 5,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '160 2nd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['160 2nd Ave', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468377000',
#   'latitude': 40.72981,
#   'longitude': -73.98658},
#  {'name': 'Dough Vale',
#   'review_count': 84,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '330 S 3rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 S 3rd St', 'New York, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13478897400',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': '$1 Pizza',
#   'review_count': 5,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '832 6th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['832 6th Ave', 'New York, NY 10001']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.7464708159905,
#   'longitude': -73.9899855852127},
#  {'name': "Rao's",
#   'review_count': 186,
#   'rating': 4.5,
#   'price': '\\$\\$\\$\\$',
#   'location': {'address1': '455 E 114th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['455 E 114th St', 'New York, NY 10029']},
#   'transactions': ['delivery'],
#   'phone': '+12127226709',
#   'latitude': 40.79392,
#   'longitude': -73.93427},
#  {'name': 'Santa Panza',
#   'review_count': 183,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1079 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1079 Broadway', 'Brooklyn, NY 11221']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13474139695',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'New York Pizza',
#   'review_count': 115,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '701 W Elms Rd',
#    'address2': 'Ste 300',
#    'address3': '',
#    'city': 'Killeen',
#    'zip_code': '76542',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['701 W Elms Rd', 'Ste 300', 'Killeen, TX 76542']},
#   'transactions': ['delivery'],
#   'phone': '+12542851758',
#   'latitude': 31.086427,
#   'longitude': -97.753939},
#  {'name': 'Wheated',
#   'review_count': 340,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '905 Church Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11218',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['905 Church Ave', 'Brooklyn, NY 11218']},
#   'transactions': ['delivery'],
#   'phone': '+13472402813',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': 'MidiCi Neapolitan Pizza',
#   'review_count': 81,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '174 N 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['174 N 4th St', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187822020',
#   'latitude': 40.71529,
#   'longitude': -73.95858},
#  {'name': "Louie's Pizza",
#   'review_count': 477,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '81-34 Baxter Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Elmhurst',
#    'zip_code': '11373',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['81-34 Baxter Ave', 'Elmhurst, NY 11373']},
#   'transactions': ['delivery'],
#   'phone': '+17184409346',
#   'latitude': 40.7459,
#   'longitude': -73.8834},
#  {'name': 'Bobwhite Counter',
#   'review_count': 828,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '94 Ave C',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['94 Ave C', 'New York, NY 10009']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122282972',
#   'latitude': 40.72365,
#   'longitude': -73.97899},
#  {'name': 'Tony’s Pizza',
#   'review_count': 1,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '128 2nd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 2nd Ave', 'New York, NY 10003']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.72834,
#   'longitude': -73.98764},
#  {'name': 'Abaita',
#   'review_count': 83,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '145 E 49th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['145 E 49th St', 'New York, NY 10017']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468085518',
#   'latitude': 40.755541483222,
#   'longitude': -73.9718742367706},
#  {'name': "Scott's Pizza Tours",
#   'review_count': 324,
#   'rating': 5.0,
#   'price': '\\$\\$',
#   'location': {'address1': '',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['New York, NY 10001']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.750244140625,
#   'longitude': -73.9970245361328},
#  {'name': "Lena's Italian Kitchen",
#   'review_count': 242,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '551 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['551 2nd Ave', 'New York, NY 10016']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468465362',
#   'latitude': 40.742664,
#   'longitude': -73.977783},
#  {'name': '99c Pizza',
#   'review_count': 8,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '297 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['297 Broadway', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13477254005',
#   'latitude': 40.7085545735202,
#   'longitude': -73.958028},
#  {'name': 'Don Angie',
#   'review_count': 429,
#   'rating': 4.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '103 Greenwich Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['103 Greenwich Ave', 'New York, NY 10014']},
#   'transactions': ['delivery'],
#   'phone': '+12128898884',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Non Solo Piada',
#   'review_count': 362,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '302 W 37th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['302 W 37th St', 'New York, NY 10018']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122160616',
#   'latitude': 40.75414,
#   'longitude': -73.99245},
#  {'name': 'Greenpoint Original Italian Pizza',
#   'review_count': 11,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '93 Norman Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['93 Norman Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery'],
#   'phone': '+19179091819',
#   'latitude': 40.7256746906384,
#   'longitude': -73.9513858978921},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 297,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '227 Lenox Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['227 Lenox Ave', 'New York, NY 10027']},
#   'transactions': ['delivery'],
#   'phone': '+16469284870',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': "Baker's Pizza",
#   'review_count': 106,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '754 10th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['754 10th Ave', 'New York, NY 10019']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19172620722',
#   'latitude': 40.76546,
#   'longitude': -73.991},
#  {'name': 'Pasta by Hudson',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '180 7th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['180 7th Ave', 'New York, NY 10011']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.7427486,
#   'longitude': -73.9969892},
#  {'name': '&pizza - Astor Place',
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '740 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['740 Broadway', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.729798,
#   'longitude': -73.9926904},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 26,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '14 Rector St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14 Rector St', 'New York, NY 10006']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124060918',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Biga Bite',
#   'review_count': 118,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '3 Clinton St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Clinton St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19172658453',
#   'latitude': 40.72123,
#   'longitude': -73.98408},
#  {'name': 'Cuts & Slices',
#   'review_count': 165,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '93 Howard Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11233',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['93 Howard Ave', 'Brooklyn, NY 11233']},
#   'transactions': ['delivery'],
#   'phone': '+17185522652',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': "Tony's Pizza Spot",
#   'review_count': 51,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '431 DeKalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['431 DeKalb Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery'],
#   'phone': '+17186226395',
#   'latitude': 40.6905899047852,
#   'longitude': -73.9601821899414},
#  {'name': 'Cypriana Cafe Pizzeria',
#   'review_count': 5,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '4702 37th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Long Island City',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4702 37th St', 'Long Island City, NY 11101']},
#   'transactions': [],
#   'phone': '+17183611747',
#   'latitude': 40.74213,
#   'longitude': -73.928557},
#  {'name': 'Impasto',
#   'review_count': 17,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '373 Waverly Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['373 Waverly Ave', 'Brooklyn, NY 11238']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.686981915031,
#   'longitude': -73.966445790681},
#  {'name': 'Slice Pizza',
#   'review_count': 33,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '700 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['700 3rd Ave', 'New York, NY 10017']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': 'Square Pizza',
#   'review_count': 25,
#   'rating': 4.5,
#   'price': 'Unknown',
# ...
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['499 7th Ave', 'New York, NY 10018']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467340303',
#   'latitude': 40.752603,
#   'longitude': -73.989115},
#  {'name': 'Pi Bakerie',
#   'review_count': 292,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '512 Broome St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['512 Broome St', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122262701',
#   'latitude': 40.72361,
#   'longitude': -74.00329},
#  {'name': 'The Little Taco House',
#   'review_count': 62,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '246 West 4th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['246 West 4th St', 'New York, NY 10014']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467191600',
#   'latitude': 40.73475,
#   'longitude': -74.00321},
#  {'name': 'Xtra Cheese Pizza',
#   'review_count': 116,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '14720 Northern Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Flushing',
#    'zip_code': '11372',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14720 Northern Blvd', 'Flushing, NY 11372']},
#   'transactions': ['delivery'],
#   'phone': '+17189613122',
#   'latitude': 40.7651362,
#   'longitude': -73.8182876},
#  {'name': '314 Pizza Pasta & Wine Bar',
#   'review_count': 106,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1260 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1260 Amsterdam Ave', 'New York, NY 10027']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16466827645',
#   'latitude': 40.810854,
#   'longitude': -73.958384},
#  {'name': 'Maspeth Pizza House',
#   'review_count': 1,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '55-60 60th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Queens',
#    'zip_code': '11378',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55-60 60th St', 'Queens, NY 11378']},
#   'transactions': [],
#   'phone': '+17183261222',
#   'latitude': 40.7256979,
#   'longitude': -73.9062846},
#  {'name': 'Quentin Pizzeria & Restaurant',
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '3211 Quentin Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11234',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3211 Quentin Rd', 'Brooklyn, NY 11234']},
#   'transactions': ['delivery'],
#   'phone': '+17183765384',
#   'latitude': 40.61318,
#   'longitude': -73.939567},
#  {'name': "Mancini's Wood-Fired Pizza",
#   'review_count': 108,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '8504 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8504 5th Ave', 'Brooklyn, NY 11209']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183335209',
#   'latitude': 40.62207,
#   'longitude': -74.02591},
#  {'name': 'Brockenzo Neapolitan Pizza',
#   'review_count': 9,
#   'rating': 5.0,
#   'price': '\\$\\$',
#   'location': {'address1': '',
#    'address2': None,
#    'address3': '',
#    'city': 'Long Island',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['Long Island, NY 11101']},
#   'transactions': [],
#   'phone': '+16315231132',
#   'latitude': 40.7503547668457,
#   'longitude': -73.9447784423828},
#  {'name': "Sorrento's",
#   'review_count': 325,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '255 W Park Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Beach',
#    'zip_code': '11561',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['255 W Park Ave', 'Long Beach, NY 11561']},
#   'transactions': [],
#   'phone': '+15168894800',
#   'latitude': 40.58874,
#   'longitude': -73.67182},
#  {'name': 'Marc Forgione',
#   'review_count': 946,
#   'rating': 4.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '134 Reade St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['134 Reade St', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129419401',
#   'latitude': 40.71647,
#   'longitude': -74.0095599},
#  {'name': 'Tableside Italian Cook Shoppe',
#   'review_count': 297,
#   'rating': 4.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '345 E 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['345 E 6th St', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468526498',
#   'latitude': 40.7266287,
#   'longitude': -73.9863384},
#  {'name': 'Scoops and Snacks',
#   'review_count': 11,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '26 Cedar St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10005',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 Cedar St', 'New York, NY 10005']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123449892',
#   'latitude': 40.7069904307,
#   'longitude': -74.0078002094},
#  {'name': 'Bella Gioia',
#   'review_count': 221,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '209 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['209 4th Ave', 'Brooklyn, NY 11217']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13472234176',
#   'latitude': 40.6775302,
#   'longitude': -73.9827215},
#  {'name': 'Roll & Go $1 Pizza',
#   'review_count': 3,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '1278 Fulton St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1278 Fulton St', 'Brooklyn, NY 11216']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.6803560256958,
#   'longitude': -73.9497350156307},
#  {'name': 'Jaks Corner',
#   'review_count': 4,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '73-02 37th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Jackson Heights',
#    'zip_code': '11372',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['73-02 37th Ave', 'Jackson Heights, NY 11372']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17188980097',
#   'latitude': 40.74868,
#   'longitude': -73.89254},
#  {'name': "Gino's Pizzeria",
#   'review_count': 82,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '439 S Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Yonkers',
#    'zip_code': '10705',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['439 S Broadway', 'Yonkers, NY 10705']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+19144235088',
#   'latitude': 40.91832,
#   'longitude': -73.89684},
#  {'name': 'Il Baretto To Go',
#   'review_count': 40,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '790 11th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['790 11th Ave', 'New York, NY 10019']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122450490',
#   'latitude': 40.76873,
#   'longitude': -73.99224},
#  {'name': "Lee's Tavern",
#   'review_count': 529,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '60 Hancock St',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Hancock St', 'Staten Island, NY 10305']},
#   'transactions': ['delivery'],
#   'phone': '+17186679749',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': 'DOUGH By Licastri',
#   'review_count': 180,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1456 Richmond Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1456 Richmond Rd', 'Staten Island, NY 10304']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17186681600',
#   'latitude': 40.59391,
#   'longitude': -74.09948},
#  {'name': 'Low Fidelity',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '328 Palisade Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Jersey City',
#    'zip_code': '07307',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['328 Palisade Ave', 'Jersey City, NJ 07307']},
#   'transactions': ['delivery'],
#   'phone': '+12017953600',
#   'latitude': 40.73977,
#   'longitude': -74.04679},
#  {'name': 'Smorgasburg - Prospect Park',
#   'review_count': 305,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': 'Prospect Park',
#    'address2': '',
#    'address3': '',
#    'city': 'Breeze Hill',
#    'zip_code': '11225',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['Prospect Park', 'Breeze Hill, NY 11225']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.6590168776025,
#   'longitude': -73.96627542547},
#  {'name': 'Tramonti Fifth Ave',
#   'review_count': 39,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '2 W 28th St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 W 28th St', 'New York, NY 10001']},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'phone': '+12124647082',
#   'latitude': 40.74475,
#   'longitude': -73.98772},
#  {'name': 'Rustico Taverna',
#   'review_count': 9,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '65-17 Fresh Pond Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Queens',
#    'zip_code': '11385',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['65-17 Fresh Pond Rd', 'Queens, NY 11385']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13477992880',
#   'latitude': 40.70925,
#   'longitude': -73.89827},
#  {'name': 'Ita Italian Kitchen',
#   'review_count': 77,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '686 Bergen Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Jersey City',
#    'zip_code': '07304',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['686 Bergen Ave', 'Jersey City, NJ 07304']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12014358380',
#   'latitude': 40.723524,
#   'longitude': -74.07016},
#  {'name': 'New York Pizza',
#   'review_count': 1,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '83-08 37th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Jackson Heights',
#    'zip_code': '11372',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['83-08 37th Ave', 'Jackson Heights, NY 11372']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184069210',
#   'latitude': 40.749771,
#   'longitude': -73.883045},
#  {'name': "Joe's Pizza",
#   'review_count': 6,
#   'rating': 5.0,
#   'price': '\\$',
#   'location': {'address1': '710 E 187th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10458',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['710 E 187th St', 'Bronx, NY 10458']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17185843911',
#   'latitude': 40.85392,
#   'longitude': -73.88413},
#  {'name': "Pugsley's Pizza",
#   'review_count': 164,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '590 E 191st St',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10458',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['590 E 191st St', 'Bronx, NY 10458']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183650327',
#   'latitude': 40.85881,
#   'longitude': -73.88475},
#  {'name': 'Nonna Maria Brick Oven Pizza',
#   'review_count': 5,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '4108 Tonnele Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'North Bergen',
#    'zip_code': '07047',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['4108 Tonnele Ave', 'North Bergen, NJ 07047']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12013301671',
#   'latitude': 40.78235,
#   'longitude': -74.03495},
#  {'name': 'Bosino',
#   'review_count': 37,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '201 W 103rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['201 W 103rd St', 'New York, NY 10025']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467558770',
#   'latitude': 40.798755,
#   'longitude': -73.9673646},
#  {'name': 'Trattoria Napoli',
#   'review_count': 125,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '4525 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Union City',
#    'zip_code': '07087',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['4525 Broadway', 'Union City, NJ 07087']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12017585465',
#   'latitude': 40.77794,
#   'longitude': -74.01825},
#  {'name': 'Villa Meci Pizzeria',
#   'review_count': 71,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '214 Glen Cove Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Glen Cove',
#    'zip_code': '11542',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Glen Cove Ave', 'Glen Cove, NY 11542']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+15168014400',
#   'latitude': 40.8481627306549,
#   'longitude': -73.635030192143},
#  {'name': 'OddFellows Ice Cream Co.',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '\\$\\$',
#   'location': {'address1': '44 Water St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['44 Water St', 'Brooklyn, NY 11201']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17186835755',
#   'latitude': 40.70325596349647,
#   'longitude': -73.9924016193591},
#  {'name': 'I Love Panzerotti-- East Village',
#   'review_count': 10,
#   'rating': 5.0,
#   'price': 'Unknown',
#   'location': {'address1': '130 St Marks Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16465967113',
#   'latitude': 40.7266801,
#   'longitude': -73.9835791},
#  {'name': 'American Cheez',
#   'review_count': 113,
#   'rating': 4.5,
#   'price': '\\$',
#   'location': {'address1': '444 7th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['444 7th Ave', 'Brooklyn, NY 11215']},
#   'transactions': ['delivery'],
#   'phone': '+13477254665',
#   'latitude': 40.66327,
#   'longitude': -73.9848},
#  {'name': "Mama's Pizza and Cafe",
#   'review_count': 10,
#   'rating': 4.5,
#   'price': 'Unknown',
#   'location': {'address1': '80-14 Roosevelt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Jackson Heights',
#    'zip_code': '11372',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80-14 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13478480200',
#   'latitude': 40.7474050196804,
#   'longitude': -73.8853297362896}]

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(above_average) == list
assert type(above_average[0]) == dict
assert len(above_average) == 306

# %% [markdown]
# ## Isolate restaurants with a below average rating
#
# Now repeat the process for below average ratings.
#
# In the cell below, isolate restaurants that have a rating of no more than `3.5`.

# %%
# Create an empty list
# You will store restaurants in this list
below_average = []
 

# Loop over the restaurants in the dataset
# YOUR CODE HERE
for index in range(len(data_pizza)):
    data_dict =data_pizza[index]
    # Isolate the rating
    # YOUR CODE HERE
    
    # Check if the rating is no more than 3.5
    # YOUR CODE HERE
    if  data_dict['rating'] <= 3.5:
         
        below_average.append(data_dict.copy())   
        # If the rating no more than 3.5
        # Add the restaurant to the list
        # YOUR CODE HERE
below_average
# Out:
# [{'name': "Grimaldi's Pizzeria",
#   'review_count': 4683,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17188584300',
#   'latitude': 40.702583,
#   'longitude': -73.9932413},
#  {'name': "MAMA'S TOO!",
#   'review_count': 460,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '2750 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2750 Broadway', 'New York, NY 10025']},
#   'transactions': ['delivery'],
#   'phone': '+12125107256',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Piccolo Trattoria',
#   'review_count': 95,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '455 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10044',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['455 Main St', 'New York, NY 10044']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127532300',
#   'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 392,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '59 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['59 5th Ave', 'Brooklyn, NY 11217']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13477631975',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': "Ignazio's",
#   'review_count': 550,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '4 Water St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4 Water St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17185222100',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': "Juliana's - Time Out Market",
#   'review_count': 4,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '55 Water St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.703447,
#   'longitude': -73.99215},
#  {'name': 'Upside Pizza',
#   'review_count': 168,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '598 8th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['598 8th Ave', 'New York, NY 10018']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16464845244',
#   'latitude': 40.7550912,
#   'longitude': -73.9911494},
#  {'name': 'Celeste Restaurant',
#   'review_count': 920,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '502 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['502 Amsterdam Ave', 'New York, NY 10024']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12128744559',
#   'latitude': 40.78666,
#   'longitude': -73.97599},
#  {'name': 'Love & Dough',
#   'review_count': 205,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '57 Pearl St',
#    'address2': '',
#    'address3': '',
#    'city': 'DUMBO',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['57 Pearl St', 'DUMBO, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+13479873404',
#   'latitude': 40.7030253,
#   'longitude': -73.9874284},
#  {'name': 'San Matteo Pizzeria e Cucina',
#   'review_count': 331,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1559 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1559 2nd Ave', 'New York, NY 10028']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128612434',
#   'latitude': 40.7746799,
#   'longitude': -73.95443},
#  {'name': 'Maspeth Pizza',
#   'review_count': 60,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '7109 Grand Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Maspeth',
#    'zip_code': '11378',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7109 Grand Ave', 'Maspeth, NY 11378']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186395050',
#   'latitude': 40.72815,
#   'longitude': -73.89206},
#  {'name': 'Little Italy Pizza',
#   'review_count': 134,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '50 Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['50 Fulton St', 'New York, NY 10038']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125717700',
#   'latitude': 40.7081041823001,
#   'longitude': -74.0046897976739},
#  {'name': "Frank's Trattoria",
#   'review_count': 144,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '371 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['371 1st Ave', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126772991',
#   'latitude': 40.73612,
#   'longitude': -73.979473},
#  {'name': 'Best Pizza',
#   'review_count': 632,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '33 Havemeyer St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33 Havemeyer St', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17185992210',
#   'latitude': 40.7156,
#   'longitude': -73.95352},
#  {'name': 'Time Out Market New York',
#   'review_count': 287,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '55 Water St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#   'transactions': [],
#   'phone': '+19178104855',
#   'latitude': 40.7037211399782,
#   'longitude': -73.9918105285751},
#  {'name': 'Garlic New York Pizza Bar',
#   'review_count': 446,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '629 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['629 2nd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16465599500',
#   'latitude': 40.74514,
#   'longitude': -73.97584},
#  {'name': 'Corner Pizza And Wine',
#   'review_count': 3,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '130 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery'],
#   'phone': '+17188662828',
#   'latitude': 40.7148695,
#   'longitude': -73.9625803},
#  {'name': 'Patsy’s Pizzeria',
#   'review_count': 418,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '206 E 60th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['206 E 60th St', 'New York, NY 10022']},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'phone': '+12126889707',
#   'latitude': 40.76177,
#   'longitude': -73.96575},
#  {'name': "Tony Boloney's - Hoboken",
#   'review_count': 617,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '263 1st St',
#    'address2': None,
#    'address3': None,
#    'city': 'Hoboken',
#    'zip_code': '07030',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['263 1st St', 'Hoboken, NJ 07030']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12012228669',
#   'latitude': 40.7378974,
#   'longitude': -74.0343764},
#  {'name': 'Eataly NYC Downtown',
#   'review_count': 1022,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '101 Liberty St',
#    'address2': 'Fl 3',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['101 Liberty St', 'Fl 3', 'New York, NY 10006']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12128972895',
#   'latitude': 40.709716,
#   'longitude': -74.011714},
#  {'name': 'Motorino',
#   'review_count': 1085,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '349 E 12th St',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['349 E 12th St', 'Ste A', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127772644',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 357,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '177 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['177 Spring St', 'New York, NY 10012']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129664494',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': "Ganni's Pizza",
#   'review_count': 111,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '652 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['652 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['delivery'],
#   'phone': '+17182549870',
#   'latitude': 40.69419,
#   'longitude': -73.957809},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1611,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '114 10th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['114 10th Ave', 'New York, NY 10011']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127929200',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': 'Di Fara',
#   'review_count': 2,
#   'rating': 1.0,
#   'price': 'Unknown',
#   'location': {'address1': '196 Stanton St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['196 Stanton St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468288603',
#   'latitude': 40.71991504934647,
#   'longitude': -73.98312764297455},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 861,
#   'rating': 3.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '55 Water St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery'],
#   'phone': '+17186503900',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': 'Franklin Pizza',
#   'review_count': 53,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '109 Franklin St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['109 Franklin St', 'Brooklyn, NY 11222']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183492472',
#   'latitude': 40.729684,
#   'longitude': -73.957827},
#  {'name': "Saluggi's East",
#   'review_count': 110,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '399 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['399 Grand St', 'New York, NY 10002']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16468961163',
#   'latitude': 40.715948062187,
#   'longitude': -73.9873785183775},
#  {'name': 'Shelter Pizza',
#   'review_count': 311,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '80 N 7th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 N 7th St', 'Brooklyn, NY 11249']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183888338',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': "Angelo's Pizza",
#   'review_count': 563,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1697 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1697 Broadway', 'New York, NY 10019']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122458811',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': 'Koronet Pizza',
#   'review_count': 643,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '2848 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2848 Broadway', 'New York, NY 10025']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122221566',
#   'latitude': 40.80447,
#   'longitude': -73.96616},
#  {'name': "Dani's House of Pizza",
#   'review_count': 1056,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '81-28 Lefferts Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Kew Gardens',
#    'zip_code': '11415',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['81-28 Lefferts Blvd', 'Kew Gardens, NY 11415']},
#   'transactions': ['delivery'],
#   'phone': '+17188462849',
#   'latitude': 40.7090018174257,
#   'longitude': -73.830498211479},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 266,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '801 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['801 2nd Ave', 'New York, NY 10017']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128789600',
#   'latitude': 40.750427,
#   'longitude': -73.972129},
#  {'name': "Famous Original Ray's Pizza",
#   'review_count': 127,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '204 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['204 9th Ave', 'New York, NY 10011']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122431129',
#   'latitude': 40.74597,
#   'longitude': -74.0013},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 326,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '265 Union Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['265 Union Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17188558729',
#   'latitude': 40.7078768,
#   'longitude': -73.9507711},
#  {'name': "Danny's Pizzeria & Cafe",
#   'review_count': 174,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '241 Bushwick Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['241 Bushwick Ave', 'Brooklyn, NY 11206']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17183811669',
#   'latitude': 40.70787,
#   'longitude': -73.93971},
#  {'name': 'Obicà Mozzarella Bar Pizza e Cucina',
#   'review_count': 460,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '928 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['928 Broadway', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12127772754',
#   'latitude': 40.7400486,
#   'longitude': -73.9893018},
#  {'name': 'Eleven B',
#   'review_count': 212,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '174 Avenue B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['174 Avenue B', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123889811',
#   'latitude': 40.72745,
#   'longitude': -73.97974},
#  {'name': 'Pizza Mercato',
#   'review_count': 163,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '11 Waverly Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['11 Waverly Pl', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124208432',
#   'latitude': 40.73015,
#   'longitude': -73.9941599},
#  {'name': 'Neapolitan Express',
#   'review_count': 211,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '40 Wall St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10005',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['40 Wall St', 'New York, NY 10005']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16469186169',
#   'latitude': 40.70681,
#   'longitude': -74.00996},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 296,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1279 1st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10065',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1279 1st Ave', 'New York, NY 10065']},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'phone': '+12126391000',
#   'latitude': 40.7658680230835,
#   'longitude': -73.9576601066113},
#  {'name': '2 Bros Pizza',
#   'review_count': 277,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '755 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 6th Ave', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '',
#   'latitude': 40.7443525488053,
#   'longitude': -73.9919924442138},
#  {'name': 'Rosie Pizza Bar',
#   'review_count': 7,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '128 Central Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 Central Ave', 'New York, NY 11221']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17184404369',
#   'latitude': 40.6998,
#   'longitude': -73.92842},
#  {'name': "Mike's Pizza",
#   'review_count': 105,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '415 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['415 2nd Ave', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125325196',
#   'latitude': 40.7385362974077,
#   'longitude': -73.9806645185456},
#  {'name': "Harry's Italian",
#   'review_count': 264,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '225 Murray St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10282',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['225 Murray St', 'New York, NY 10282']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126081007',
#   'latitude': 40.7153762863468,
#   'longitude': -74.0139836332683},
#  {'name': '2 Bros Pizza',
#   'review_count': 597,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '32 St Marks Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 St Marks Pl', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19179990610',
#   'latitude': 40.72866,
#   'longitude': -73.988487},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 77,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '512 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['512 Grand St', 'Brooklyn, NY 11211']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17187822100',
#   'latitude': 40.71087,
#   'longitude': -73.95069},
#  {'name': 'Gnocco',
#   'review_count': 505,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '337 E 10th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['337 E 10th St', 'New York, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126771913',
#   'latitude': 40.72713,
#   'longitude': -73.9802799},
#  {'name': 'Lunetta Pizza & Restaurant',
#   'review_count': 146,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '245 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['245 3rd Ave', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12124325200',
#   'latitude': 40.736942,
#   'longitude': -73.984176},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 523,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '61 W 74th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['61 W 74th St', 'New York, NY 10023']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12125793000',
#   'latitude': 40.7785204,
#   'longitude': -73.9769718},
#  {'name': 'Stromboli Pizza',
#   'review_count': 243,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '83 Saint Marks Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['83 Saint Marks Pl', 'New York, NY 10003']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126733691',
#   'latitude': 40.72778,
#   'longitude': -73.9854299},
#  {'name': 'sLICe LIC',
#   'review_count': 403,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '48-11 Vernon Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Island City',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['48-11 Vernon Blvd', 'Long Island City, NY 11101']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17189375423',
#   'latitude': 40.74367,
#   'longitude': -73.95345},
#  {'name': "Rocky's Number II",
#   'review_count': 318,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '607 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['607 2nd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126834151',
#   'latitude': 40.74442,
#   'longitude': -73.9765},
#  {'name': "Grimaldi's",
#   'review_count': 775,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '656 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['656 6th Ave', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16464845665',
#   'latitude': 40.7412157,
#   'longitude': -73.9938935},
#  {'name': 'Roberta’s',
#   'review_count': 7,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '6 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#   'transactions': [],
#   'phone': '',
#   'latitude': 40.71613781459604,
#   'longitude': -73.9665876020738},
#  {'name': 'Champion Pizza',
#   'review_count': 79,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '2 W 14th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 W 14th St', 'New York, NY 10011']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12128989898',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': 'Yankee Pizza',
#   'review_count': 37,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '181 Ave C',
#    'address2': None,
#    'address3': '',
#    'city': 'New York City',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['181 Ave C', 'New York City, NY 10009']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+16467603334',
#   'latitude': 40.7267,
#   'longitude': -73.97727},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 64,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '70 Pine St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10270',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['70 Pine St', 'New York, NY 10270']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19172614530',
#   'latitude': 40.706518,
#   'longitude': -74.007505},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 241,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '164 William St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['164 William St', 'New York, NY 10038']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126198260',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': 'Lower East Side Pizza',
#   'review_count': 77,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '181 E Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['181 E Broadway', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16467564448',
#   'latitude': 40.7138977050781,
#   'longitude': -73.9891967773438},
#  {'name': 'La Bellezza Pizza',
#   'review_count': 15,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '315 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10007',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['315 Broadway', 'New York, NY 10007']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122273337',
#   'latitude': 40.71574,
#   'longitude': -74.00538},
#  {'name': "Tony's Pizza",
#   'review_count': 168,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '355 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['355 Graham Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183848669',
#   'latitude': 40.715049,
#   'longitude': -73.944702},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '350 3rd Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['350 3rd Ave', 'New York, NY 10010']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122132222',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 116,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '388 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['388 6th Ave', 'New York, NY 10011']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127800020',
#   'latitude': 40.733114,
#   'longitude': -73.9995607},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 892,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '111 MacDougal St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['111 MacDougal St', 'New York, NY 10012']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16462786100',
#   'latitude': 40.7298659578295,
#   'longitude': -74.0007890374328},
#  {'name': 'WILD',
#   'review_count': 440,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '535 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['535 Hudson St', 'New York, NY 10014']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129292920',
#   'latitude': 40.73474,
#   'longitude': -74.00632},
#  {'name': "Ray's Pizza & Bagel Cafe",
#   'review_count': 292,
#   'rating': 2.5,
#   'price': '\\$',
#   'location': {'address1': '2 St Marks Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 St Marks Pl', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12125336656',
#   'latitude': 40.72929,
#   'longitude': -73.98965},
#  {'name': 'Social Drink and Food',
#   'review_count': 69,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '570 10th Ave',
#    'address2': '(42nd & Tenth) YOTEL, Fl 4',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['570 10th Ave',
#     '(42nd & Tenth) YOTEL, Fl 4',
#     'New York, NY 10036']},
#   'transactions': ['delivery'],
#   'phone': '+19172396560',
#   'latitude': 40.759178,
#   'longitude': -73.995461},
#  {'name': "Ben's Pizzeria",
#   'review_count': 288,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '123 MacDougal St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['123 MacDougal St', 'New York, NY 10012']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126770976',
#   'latitude': 40.7304,
#   'longitude': -74.00027},
#  {'name': "Jimmy's Pizzeria",
#   'review_count': 54,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '561 Wilson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11207',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['561 Wilson Ave', 'Brooklyn, NY 11207']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184553237',
#   'latitude': 40.6913995614207,
#   'longitude': -73.9090716926598},
#  {'name': 'Picasso Pizza',
#   'review_count': 130,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '303 S End Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10280',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['303 S End Ave', 'New York, NY 10280']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123212616',
#   'latitude': 40.710402,
#   'longitude': -74.016469},
#  {'name': 'Prince Pizza',
#   'review_count': 44,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '86 Nassau Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['86 Nassau Ave', 'Brooklyn, NY 11222']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183890501',
#   'latitude': 40.7238165289164,
#   'longitude': -73.9504531770945},
#  {'name': "Tony's Pizza On Nostrand",
#   'review_count': 127,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '850 Nostrand Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11225',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['850 Nostrand Ave', 'Brooklyn, NY 11225']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183638300',
#   'latitude': 40.6688210975502,
#   'longitude': -73.9507952858792},
#  {'name': 'Gotham Pizza',
#   'review_count': 164,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '144 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['144 9th Ave', 'New York, NY 10011']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129898858',
#   'latitude': 40.74381,
#   'longitude': -74.00295},
#  {'name': 'Freehold In The Park',
#   'review_count': 9,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '20 Union Sq W',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['20 Union Sq W', 'New York, NY 10003']},
#   'transactions': [],
#   'phone': '+16469083333',
#   'latitude': 40.7355533,
#   'longitude': -73.9916237},
#  {'name': 'marcellino tratoria & pizzeria',
#   'review_count': 74,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '178 Mulberry St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['178 Mulberry St', 'New York, NY 10012']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16469984576',
#   'latitude': 40.72066,
#   'longitude': -73.99666},
#  {'name': 'Giovanni',
#   'review_count': 348,
#   'rating': 2.5,
#   'price': '\\$\\$',
#   'location': {'address1': '579 Grand Concourse',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['579 Grand Concourse', 'Bronx, NY 10451']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184026996',
#   'latitude': 40.81942,
#   'longitude': -73.92714},
#  {'name': "Rocky's Pizza 14th St",
#   'review_count': 158,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '304 W 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['304 W 14th St', 'New York, NY 10014']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122422345',
#   'latitude': 40.740022,
#   'longitude': -74.003288},
#  {'name': "Sal's Pizzeria",
#   'review_count': 127,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '305 Court St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['305 Court St', 'Brooklyn, NY 11231']},
#   'transactions': ['delivery'],
#   'phone': '+17188526890',
#   'latitude': 40.68357,
#   'longitude': -73.99504},
#  {'name': 'Joey Pepperonis Pizza',
#   'review_count': 130,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '381 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['381 Broadway', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122193555',
#   'latitude': 40.7182503,
#   'longitude': -74.0031891},
#  {'name': "New York Sal's Pizza",
#   'review_count': 71,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '696 10th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['696 10th Ave', 'New York, NY 10019']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122473628',
#   'latitude': 40.7637252807617,
#   'longitude': -73.9921112060547},
#  {'name': 'Little Italy Pizza',
#   'review_count': 119,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '122 University Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['122 University Pl', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129894225',
#   'latitude': 40.7347831726074,
#   'longitude': -73.9922409057617},
#  {'name': "John's Pizzeria",
#   'review_count': 256,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '87 Sussex St',
#    'address2': '',
#    'address3': '',
#    'city': 'Jersey City',
#    'zip_code': '07302',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['87 Sussex St', 'Jersey City, NJ 07302']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12014334411',
#   'latitude': 40.714442466852,
#   'longitude': -74.037385960943},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 36,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '482 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['482 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187890600',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'Rocco Pizza',
#   'review_count': 184,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '765 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['765 Dekalb Ave', 'Brooklyn, NY 11216']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17182189200',
#   'latitude': 40.69224,
#   'longitude': -73.945849},
#  {'name': 'Motorino',
#   'review_count': 246,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '510 Columbus Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['510 Columbus Ave', 'New York, NY 10024']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+19176757581',
#   'latitude': 40.7855672,
#   'longitude': -73.9730817},
#  {'name': 'Bklyn Pizza',
#   'review_count': 150,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '36 Ralph Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bedford-Stuyvesant',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['36 Ralph Ave', 'Bedford-Stuyvesant, NY 11221']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184848787',
#   'latitude': 40.6890640258789,
#   'longitude': -73.9241943359375},
#  {'name': 'Table 87 - Industry City',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '238 36th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['238 36th St', 'Brooklyn, NY 11232']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184992198',
#   'latitude': 40.6560905,
#   'longitude': -74.0074913},
#  {'name': 'Mariella Pizza',
#   'review_count': 114,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '965 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['965 Lexington Ave', 'New York, NY 10021']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12122492065',
#   'latitude': 40.769161,
#   'longitude': -73.962821},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 240,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '18 Wyckoff Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['18 Wyckoff Ave', 'Brooklyn, NY 11237']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183860333',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': "John's of Times Square",
#   'review_count': 2157,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '260 W 44th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['260 W 44th St', 'New York, NY 10036']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123917560',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': "L' Angolo Tribeca",
#   'review_count': 162,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '190-A Duane St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['190-A Duane St', 'New York, NY 10013']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126253333',
#   'latitude': 40.71734,
#   'longitude': -74.01044},
#  {'name': "Lazzara's Pizza",
#   'review_count': 289,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '221 W 38th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 W 38th St', 'New York, NY 10018']},
#   'transactions': ['delivery'],
#   'phone': '+12129447792',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': 'Dough Boys',
#   'review_count': 316,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '451 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['451 3rd Ave', 'New York, NY 10016']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126861211',
#   'latitude': 40.74383167116657,
#   'longitude': -73.97924070856227},
#  {'name': 'Krispy Pizza',
#   'review_count': 228,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '33 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Jersey City',
#    'zip_code': '07302',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['33 Hudson St', 'Jersey City, NJ 07302']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12016857313',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': 'Pizza Park',
#   'review_count': 320,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '1233 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1233 1st Ave', 'New York, NY 10021']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12128796444',
#   'latitude': 40.764380718592,
#   'longitude': -73.958705663681},
#  {'name': "Mimi's Italian Restaurant & Piano Bar",
#   'review_count': 317,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '984 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['984 2nd Ave', 'New York, NY 10022']},
#   'transactions': [],
#   'phone': '+12126884692',
#   'latitude': 40.75611,
#   'longitude': -73.96728},
#  {'name': 'Altro Paradiso',
#   'review_count': 176,
#   'rating': 3.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '234 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['234 Spring St', 'New York, NY 10013']},
#   'transactions': ['delivery'],
#   'phone': '+16469520828',
#   'latitude': 40.72549,
#   'longitude': -74.00489},
#  {'name': "Rocco's Pizza",
#   'review_count': 109,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '148 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 8th Ave', 'New York, NY 10011']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12126339555',
#   'latitude': 40.741764,
#   'longitude': -74.000828},
#  {'name': 'Porta',
#   'review_count': 1123,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '135 Newark Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Jersey City',
#    'zip_code': '07302',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['135 Newark Ave', 'Jersey City, NJ 07302']},
#   'transactions': ['delivery'],
#   'phone': '+12015445199',
#   'latitude': 40.7200699,
#   'longitude': -74.0437622},
#  {'name': "Little Luzzo's",
#   'review_count': 170,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '119 E 96th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['119 E 96th St', 'New York, NY 10128']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12123692300',
#   'latitude': 40.786295,
#   'longitude': -73.9515269},
#  {'name': 'Screamer’s Pizzeria',
#   'review_count': 148,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '685 Franklin Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['685 Franklin Ave', 'Brooklyn, NY 11238']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17186236000',
#   'latitude': 40.67512,
#   'longitude': -73.95623},
#  {'name': "Monty Q's",
#   'review_count': 234,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '158 Montague St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['158 Montague St', 'Brooklyn, NY 11201']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+17182462000',
#   'latitude': 40.6942,
#   'longitude': -73.99299},
#  {'name': 'Bravo Pizza',
#   'review_count': 117,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '257 Park Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['257 Park Ave S', 'New York, NY 10010']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122536090',
#   'latitude': 40.73863,
#   'longitude': -73.98727},
#  {'name': '99 Cent Pizza',
#   'review_count': 9,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '177 E Houston St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['177 E Houston St', 'New York, NY 10002']},
#   'transactions': ['delivery'],
#   'phone': '',
#   'latitude': 40.7226666559613,
#   'longitude': -73.9883711631345},
#  {'name': 'Via Roma Pizza Bar',
#   'review_count': 56,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '445 Court St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['445 Court St', 'Brooklyn, NY 11231']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+19293379714',
#   'latitude': 40.6780373,
#   'longitude': -73.9977648},
#  {'name': "Libretto's Pizzeria",
#   'review_count': 191,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '546 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['546 3rd Ave', 'New York, NY 10016']},
#   'transactions': ['delivery', 'pickup'],
#   'phone': '+12122136445',
#   'latitude': 40.74727,
#   'longitude': -73.97721},
#  {'name': 'Enzo Bruni La Pizza Gourmet',
#   'review_count': 6,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '265 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
# ...
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '186 Columbus Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Columbus Ave', 'New York, NY 10023']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127210066',
#   'latitude': 40.77523,
#   'longitude': -73.98075},
#  {'name': 'Artichoke Basille’s Pizza',
#   'review_count': 24,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '1410 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1410 Broadway', 'New York, NY 10018']},
#   'transactions': ['delivery'],
#   'phone': '+12126008635',
#   'latitude': 40.75319111073853,
#   'longitude': -73.98703214683245},
#  {'name': "Big Al's Chicago Style Pizza",
#   'review_count': 73,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '9 Thames St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9 Thames St', 'New York, NY 10006']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12129643269',
#   'latitude': 40.7089285616514,
#   'longitude': -74.0117729569844},
#  {'name': 'Brooklyn Ice Cream Factory',
#   'review_count': 237,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '14 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14 Old Fulton St', 'Brooklyn, NY 11201']},
#   'transactions': [],
#   'phone': '+17185225211',
#   'latitude': 40.702635,
#   'longitude': -73.994553},
#  {'name': 'OMG Pizzeria',
#   'review_count': 147,
#   'rating': 2.5,
#   'price': '\\$',
#   'location': {'address1': '1307 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1307 Myrtle Ave', 'Brooklyn, NY 11221']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17184554550',
#   'latitude': 40.69817,
#   'longitude': -73.92558},
#  {'name': 'Royal Pizzeria Restaurant',
#   'review_count': 7,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '945A Pennsylvania Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11207',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['945A Pennsylvania Ave', 'Brooklyn, NY 11207']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17182720108',
#   'latitude': 40.655174,
#   'longitude': -73.887446},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 219,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1000 Willow Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Hoboken',
#    'zip_code': '07030',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['1000 Willow Ave', 'Hoboken, NJ 07030']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12016838134',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'FREEHOLD',
#   'review_count': 535,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '45 S 3rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['45 S 3rd St', 'Brooklyn, NY 11249']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17183887591',
#   'latitude': 40.7136054,
#   'longitude': -73.965905},
#  {'name': 'The Commodore',
#   'review_count': 599,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '366 Metropolitan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['366 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17182187632',
#   'latitude': 40.7138257110445,
#   'longitude': -73.9556050300598},
#  {'name': 'Dumpling Man',
#   'review_count': 846,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '100 Saint Marks Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['100 Saint Marks Pl', 'New York, NY 10009']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12125052121',
#   'latitude': 40.727171,
#   'longitude': -73.9847508},
#  {'name': 'Little Italy Pizza',
#   'review_count': 62,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '958 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['958 3rd Ave', 'New York, NY 10022']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123553434',
#   'latitude': 40.7605713,
#   'longitude': -73.9674812},
#  {'name': "Armando's Pizza",
#   'review_count': 75,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '1413 Rockaway Pkwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11236',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1413 Rockaway Pkwy', 'Brooklyn, NY 11236']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17182579723',
#   'latitude': 40.645742,
#   'longitude': -73.9027409},
#  {'name': 'sLICe Astoria',
#   'review_count': 178,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '37-08 30th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Astoria',
#    'zip_code': '11103',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37-08 30th Ave', 'Astoria, NY 11103']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17186069258',
#   'latitude': 40.76432,
#   'longitude': -73.91649},
#  {'name': 'Gemma',
#   'review_count': 670,
#   'rating': 3.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '335 Bowery',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['335 Bowery', 'New York, NY 10003']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12125057300',
#   'latitude': 40.72609,
#   'longitude': -73.99166},
#  {'name': 'Gotham Pizza',
#   'review_count': 198,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '852 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['852 8th Ave', 'New York, NY 10019']},
#   'transactions': ['delivery'],
#   'phone': '+12122582288',
#   'latitude': 40.7630081,
#   'longitude': -73.9851913},
#  {'name': 'Majestic Pizza and Calzones',
#   'review_count': 132,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '8 Cortlandt St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10007',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8 Cortlandt St', 'New York, NY 10007']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123494046',
#   'latitude': 40.7101045,
#   'longitude': -74.0103076},
#  {'name': 'King',
#   'review_count': 179,
#   'rating': 3.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '18 King St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['18 King St', 'New York, NY 10014']},
#   'transactions': [],
#   'phone': '+19178251618',
#   'latitude': 40.7275,
#   'longitude': -74.00346},
#  {'name': "Gargiulo's",
#   'review_count': 255,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '2911 W 15th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11224',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2911 W 15th St', 'Brooklyn, NY 11224']},
#   'transactions': ['delivery'],
#   'phone': '+17182664891',
#   'latitude': 40.57641,
#   'longitude': -73.98244},
#  {'name': 'Rivoli Pizza',
#   'review_count': 19,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '180 7th Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['180 7th Ave S', 'New York, NY 10014']},
#   'transactions': ['delivery'],
#   'phone': '+12126912704',
#   'latitude': 40.736145,
#   'longitude': -74.0015335},
#  {'name': 'New Fresh Pizza',
#   'review_count': 20,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '2703 Church Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11226',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2703 Church Ave', 'Brooklyn, NY 11226']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13474446552',
#   'latitude': 40.6506679033418,
#   'longitude': -73.952229655276},
#  {'name': 'Parm',
#   'review_count': 373,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '250 Vesey St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10080',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['250 Vesey St', 'New York, NY 10080']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127764927',
#   'latitude': 40.7144307123699,
#   'longitude': -74.0161083107869},
#  {'name': "Hudson's Square Food Court",
#   'review_count': 33,
#   'rating': 2.5,
#   'price': '\\$\\$',
#   'location': {'address1': '333 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['333 Hudson St', 'New York, NY 10013']},
#   'transactions': ['delivery'],
#   'phone': '+12123672192',
#   'latitude': 40.727064,
#   'longitude': -74.007538},
#  {'name': 'Wild Park Slope',
#   'review_count': 291,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '148 5th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 5th Ave', 'Brooklyn, NY 11217']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+13479874525',
#   'latitude': 40.678273,
#   'longitude': -73.979376},
#  {'name': 'Becco',
#   'review_count': 2869,
#   'rating': 3.5,
#   'price': '\\$\\$\\$',
#   'location': {'address1': '355 W 46th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['355 W 46th St', 'New York, NY 10036']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123977597',
#   'latitude': 40.76083,
#   'longitude': -73.98981},
#  {'name': 'La Trattoria',
#   'review_count': 78,
#   'rating': 3.0,
#   'price': '\\$',
#   'location': {'address1': '844 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['844 2nd Ave', 'New York, NY 10017']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126825656',
#   'latitude': 40.75161,
#   'longitude': -73.97069},
#  {'name': 'Bricklyn Pizza',
#   'review_count': 22,
#   'rating': 3.5,
#   'price': 'Unknown',
#   'location': {'address1': '1240 Hancock St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1240 Hancock St', 'Brooklyn, NY 11221']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187585858',
#   'latitude': 40.692363382489,
#   'longitude': -73.9109713956714},
#  {'name': "Joey's Pizza",
#   'review_count': 136,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '6907 Grand Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Maspeth',
#    'zip_code': '11378',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6907 Grand Ave', 'Maspeth, NY 11378']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187795880',
#   'latitude': 40.726213,
#   'longitude': -73.895178},
#  {'name': 'BD PIZZA',
#   'review_count': 20,
#   'rating': 2.5,
#   'price': '\\$',
#   'location': {'address1': '105 Stanton St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['105 Stanton St', 'New York, NY 10002']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12123350803',
#   'latitude': 40.72106,
#   'longitude': -73.98758},
#  {'name': 'Serafina Fabulous Pizza',
#   'review_count': 354,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1022 Madison Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1022 Madison Ave', 'New York, NY 10075']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12127342676',
#   'latitude': 40.7762350782493,
#   'longitude': -73.9623423504256},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 416,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1758 Victory Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10314',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1758 Victory Blvd', 'Staten Island, NY 10314']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189810887',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': "Leo's Pizza",
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '31-01 36th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['31-01 36th Ave', 'Astoria, NY 11106']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187218700',
#   'latitude': 40.7566866,
#   'longitude': -73.9296278},
#  {'name': 'V & T Pizzeria & Restaurant',
#   'review_count': 357,
#   'rating': 3.0,
#   'price': '\\$\\$',
#   'location': {'address1': '1024 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1024 Amsterdam Ave', 'New York, NY 10025']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+12126631708',
#   'latitude': 40.80334,
#   'longitude': -73.96383},
#  {'name': 'Brothers Pizza',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '647 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['647 4th Ave', 'Brooklyn, NY 11232']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17187681700',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': 'Lea',
#   'review_count': 338,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '1022 Cortelyou Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11218',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1022 Cortelyou Rd', 'Brooklyn, NY 11218']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+17189287100',
#   'latitude': 40.63943,
#   'longitude': -73.96801},
#  {'name': "Umberto's Pizzeria & Restaurant",
#   'review_count': 790,
#   'rating': 3.5,
#   'price': '\\$\\$',
#   'location': {'address1': '633 Jericho Tpke',
#    'address2': '',
#    'address3': '',
#    'city': 'New Hyde Park',
#    'zip_code': '11040',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['633 Jericho Tpke', 'New Hyde Park, NY 11040']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+15164377698',
#   'latitude': 40.732218,
#   'longitude': -73.68728},
#  {'name': 'Bardolino Pizza',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '\\$',
#   'location': {'address1': '1505 Lexington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1505 Lexington Ave', 'New York, NY 10029']},
#   'transactions': ['pickup', 'delivery'],
#   'phone': '+16468501706',
#   'latitude': 40.78665,
#   'longitude': -73.95019}]

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(below_average) == list
assert type(below_average[0]) == dict
assert len(below_average) == 247

# %% [markdown]
# ## Calculate average review counts for both groups
#
# Now that you've isolated above average and below average restaurants, you can calculate the average number of reviews received by both groups.
#
# To do this, you will need to isolate the review counts for both groups, and calculate their average.
#
# The code for isolating the review counts will look very similar to code you have previously written, which is a good sign that a function should be defined!
#
# In the cell below, define a function called `isolate_values` that receives two arguments:
# 1. A list of dictionaries
# 2. A string indicating the key that should be isolated for each dictionary
#
# This function should:
# - Loop over every dictionary in the inputted list
# - Pull out the value assigned to the inputted key
# - Append the value to a new list
# - Return the new list of values

# %%
def isolate_values(dictionaries, key):
    # Create an empty list
    # for storing data
    list_values = []
    d_dict ={} 
    # YOUR CODE HERE
    
    # Loop over every dicionary 
    # YOUR CODE HERE
    
    for index in range(len(dictionaries)):
        
        
        # Isolate the value of the dictionary with the `key`
        # YOUR CODE HERE
        d_dict=dictionaries[index] 
        for i in d_dict:
            if i == key:
              
                list_values.append(d_dict[i])
            
        
        # Append the value to the list
        # YOUR CODE HERE
    
    # Return the list of values
    # YOUR CODE HERE
    return list_values

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
from types import FunctionType

assert type(isolate_values) == FunctionType
assert type(isolate_values([{'test': 1}], 'test')) == list
assert len(isolate_values([{'test': 1}], 'test')) == 1
assert len(isolate_values(above_average, 'name')) == len(above_average)
assert isolate_values(above_average, 'name')[-1] == above_average[-1]['name']

# %% [markdown]
# Now use the `isolate_values` function to create a list called `abv_avg_rev_cnts` that contains the review counts for every above average restaurant.

# %%
# Replace None with your code
abv_avg_rev_cnts = isolate_values(above_average,'review_count')

# %% [markdown]
# Now use the `isolate_values` function to create a list called `blw_avg_rev_cnts` that contains the review counts for every below average restaurant.

# %%
# Replace None with your code
blw_avg_rev_cnts = isolate_values(below_average,'review_count')

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_rev_cnts) == list
assert type(abv_avg_rev_cnts[0]) == int
assert type(blw_avg_rev_cnts) == list
assert type(blw_avg_rev_cnts[0]) == int
assert len(abv_avg_rev_cnts) == len(above_average)
assert len(blw_avg_rev_cnts) == len(below_average)
assert abv_avg_rev_cnts[101] == above_average[101]['review_count']
assert blw_avg_rev_cnts[101] == below_average[101]['review_count']

# %% [markdown]
# Now that you've isolated the review counts for both groups, you can calculate the average review count!
#
# But before you do that, you should inspect the distribution of review counts to make sure `mean` is an appropriate measure of centrality.
#
# In the cell below, we plot a histogram for above average and below average restaurant review counts.

# %%
# Initialize a matplotlib subplot
# with 1 row and 2 columns
fig, ax = plt.subplots(1,2, figsize=(15,6))

# Plot a histogram of below average review counts
# on the first axis
ax[0].hist(blw_avg_rev_cnts)

# Set the title for the first axis
# to "Below Average - Review Counts"
ax[0].set_title("Below Average - Review Counts")

# Plot a histogram of above average review counts
# on the first axis
ax[1].hist(abv_avg_rev_cnts)

# Set the title for the first axis
# to "Above Average - Review Counts"
ax[1].set_title("Above Average - Review Counts");

# %% [markdown]
# **Interpret the above visualizations. What statistic is best suited for these data?**

# %% [markdown]
# The resturants with above average rating had more reviews than the resturants that had below average rating

# %% [markdown]
# In the cell below, calculate the average review count for above average and below average restaurants.

# %%
# Import numpy
# YOUR CODE HERE
import numpy as np
array_from_abv = np.array(abv_avg_rev_cnts)
array_from_blw = np.array(blw_avg_rev_cnts)

length = len(array_from_abv)
total = sum(array_from_abv)
    
# Replace None with your code
abv_avg_rev_cnt_center = total/length
length = len(array_from_blw)
total = sum(array_from_blw)
blw_avg_rev_cnt_center = total/length

print('Above average review count:', abv_avg_rev_cnt_center)
print('Below average review count:', blw_avg_rev_cnt_center)
# Out:
# Above average review count: 189.3856209150327
# Below average review count: 285.99595141700405

# %% [markdown]
# **Interpret the average review count for both groups. How does this relate to your client's claims?**

# %% [markdown]
# Average review count of above average resturants is 189.3856209150327
# Average review count of below average resturants is 285.99595141700405.
# Below Average rating resturants have higher rating reviews

# %% [markdown]
# ## Count the price option frequency
#
# The `price` variable in the dataset is a string of dollar signs indicating how expensive a restaurant's price point is.
#
# In the cell below, write a for loop that counts how frequently a given price point appears for the `above_average` dataset

# %%
# Create an empty dictionary to store the
# counts for each price point
abv_avg_prices = {}
x = 0
y=0
z=0
q=0
p=0
# Loop over the above average restaurants
# YOUR CODE HERE
for index in range(len(above_average)):
    d_dist =above_average[index]
     
    
    # Isolate the price point for the restuarant
    # YOUR CODE HERE
    
    # Check if the price has been added to the dictionary
    # YOUR CODE HERE
     
    if d_dist['price'].count('$')== 1:
        x+=1
    elif d_dist['price'].count('$')== 2:
        y+=1
    elif d_dist['price'].count('$')== 3:
        z+=1
    elif d_dist['price'].count('$')== 4:
        q+=1
    else:
        p+=1
    
        
            # If the price is already a key in the dictionary
            # Add one to the count for that price point
            # YOUR CODE HERE
             
    
 
    # If the price has not been added to the dictionary
    # Else set the price as the key and the value as the integer `1`
    # YOUR CODE HERE
abv_avg_prices['\\$']=x
abv_avg_prices['\\$\\$']=y
abv_avg_prices['\\$\\$\\$']=z
abv_avg_prices['\\$\\$\\$\\$']=q
abv_avg_prices['Unknown']=p

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_prices) == dict
assert len(abv_avg_prices) == 5
assert '\\$\\$\\$\\$' in abv_avg_prices

# %% [markdown]
# **Now reapply the same process, but instead calculate the price point frequencies for the `below_average` dataset.**

# %%
# Create an empty dictionary to store the
# counts for each price point
# YOUR CODE HERE
blw_avg_prices = {}
x = 0
y=0
z=0
p=0
# Loop over the below average restaurants
# YOUR CODE HERE

for i in range(len(below_average)):
    # Isolate the price point for the restuarant
    # YOUR CODE HERE
    
    # Check if the price has been added to the dictionary
    # YOUR CODE HERE
    if below_average[i]['price'].count('$')== 1:
        x+=1
    elif below_average[i]['price'].count('$')== 2:
        y+=1
    elif below_average[i]['price'].count('$')== 3:
        z+=1
    else:
        p+=1
            # If the price is already a key in the dictionary
            # Add one to the count for that price point
            # YOUR CODE HERE
            
    # If the price has not been added to the dictionary
    # Set the price as the key and the value as the integer `1`
    # YOUR CODE HERE
blw_avg_prices['\\$']=x
blw_avg_prices['\\$\\$']=y
blw_avg_prices['\\$\\$\\$']=z
blw_avg_prices['Unknown']=p

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(blw_avg_prices) == dict
assert len(blw_avg_prices) == 4
assert '\\$' in blw_avg_prices

# %% [markdown]
# ## Create a bar plot that sets the frequency of each price point as the y axis

# %%
# Create a matplotlib subplot with 1 row and 2 columns
# YOUR CODE HERE
new_figure, (ax1, ax2) = plt.subplots(figsize=(15,6), ncols=2)
 
# Isolate keys of the below average price count dictionary
# This will be the x-axis
# YOUR CODE HERE
 
x=['\\$', '\\$\\$', '\\$\\$\\$', 'Unknown']
# Isolate the values of the below average price count dictionary
# This will be the y-axis
# YOUR CODE HERE
y=[]
 
for price in blw_avg_prices:
    y.append(blw_avg_prices[price])
     
     
#Plot the below average price point counts as a bar plot
# on the first axis
# YOUR CODE HERE
ax1.plot(x, y)
# Set the title for the first axis
# to the string "Below Average"
# YOUR CODE HERE3
ax1.set_title ('Below Average') 

# Isolate keys of the above average price count dictionary
# This will be the x-axis
# YOUR CODE HERE
x_new=['\\$', '\\$\\$', '\\$\\$\\$', '\\$\\$\\$\\$' ,'Unknown'] 
 
# Isolate the values of the above average price count dictionary
# This will be the y-axis
# YOUR CODE HERE
y_new=[]
 
for price in abv_avg_prices:
    y_new.append(abv_avg_prices[price]) 
     
# Plot the above average price counts as a bar plot
# on the second axis
# YOUR CODE HERE
ax2.plot(x_new, y_new) 
# Set the title for the second axis to 
# the string 'Above Average'
# YOUR CODE HERE
ax2.set_title ('Above Average')
# Out:
# Text(0.5, 1.0, 'Above Average')

# %% [markdown]
# **Interpret the above visualization. How does it relate to your client's claims?**

# %% [markdown]
# Below average resturants had low prices and above average returants had higer prices

# %% [markdown]
# ## Analyze restaurant location
#
# In the cell below, use the `isolate_values` function to isolate `longitude` and `latitude` for above and below average restaurants.

# %%
# Replace None with your code

# Isolate longitude for above average restaurants
abv_avg_lon = isolate_values(above_average,'longitude')

# Isolate latitude for above average restaurants
abv_avg_lat = isolate_values(above_average,'latitude')

# Isolate longitude for below average restaurants
blw_avg_lon = isolate_values(below_average ,'longitude')

# Isolate latitude for below average restaurants
blw_avg_lat = isolate_values(below_average ,'latitude')
 
plt.figure(figsize=(15,6))
plt.scatter(abv_avg_lon, abv_avg_lat, label='Above')
plt.scatter(blw_avg_lon, blw_avg_lat, label='Below')
plt.legend();

# %% [markdown]
# ## Remove the outlier
#
# There is one restaurant in the above average dataset with a location dramatically west and south of all other observations. Let's remove that restaurant from the above average dataset and regenerate the scatter plot.

# %%
# Create an empty list
# that will contain data with
# the outlier removed
no_outliers = [] # YOUR CODE HERE
 
# Create an empty list to append the outlier
outlier = [] # YOUR CODE HERE

# Loop over every restaurant in the above average dataset
# YOUR CODE HERE
for index in range(len(above_average)):
    d_dict1 =above_average[index]
        
    # Isolate the restaurant's longitude
    # YOUR CODE HERE
    
    # Check if the longitude value is greater than the integer -90
    # YOUR CODE HERE
    if d_dict1['longitude'] > -90:   
        # Append the restaurant to the no_outliers list
        # YOUR CODE HERE
         
         
        no_outliers.append(d_dict1.copy()) 
        
    if d_dict1['longitude'] < -90:  
        outlier.append(d_dict1['name'])       
    # If longitude is less than -90 it is an outlier
    # and should be appended to the outlier list
    # YOUR CODE HERE

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(no_outliers) == list
assert type(outlier) == list
assert len(no_outliers) == len(above_average) - 1
assert len(outlier) == 1

# %% [markdown]
# Now regenerate the longitude and latitude for above average restaurants using the `no_outliers` dataset, and regenerate the scatter plot!

# %%
abv_avg_lon = isolate_values(no_outliers,'longitude')
abv_avg_lat = isolate_values(no_outliers,'latitude')

plt.figure(figsize=(15,6))
plt.scatter(abv_avg_lon, abv_avg_lat, label='Above')
plt.scatter(blw_avg_lon, blw_avg_lat, label='Below')
plt.legend();

# %% [markdown]
# Nice. This is much more interesting.

# %% [markdown]
# ## Plot the distribution of latitude and longitude
#
# To get a better sense about how latitude and longitude are working, in the cell below plot histograms for latitude and longitude.

# %%
# Create a matplotlib subplot with 1 row and 2 columns
# YOUR CODE HERE
fig, ax = plt.subplots(1,2, figsize=(15,6))
# Plot a histogram of above average longitude
# on the first subplot axis. Set alpha to .6
# Set label to the string "Above"
# YOUR CODE HERE
ax[0].hist(abv_avg_lon ,label='Above',alpha=0.6)
 
# Plot a histogram of below average longitude
# on the first subplot axis. Set alpha to .6
# Set label to the string "Below"
# YOUR CODE HERE
ax[0].hist(blw_avg_lon,label='Below',alpha=0.6)
 
# Set the title for the first subplot axis
# to the string "Longitude"
# YOUR CODE HERE
 
ax[0].set_title("Longitude")

# Plot a histogram of above average latitude
# on the second subplot axis. Set alpha to .6
# Set label to the string "Above"
# YOUR CODE HERE
ax[1].hist(abv_avg_lat,label='Above' , alpha=0.6)
 
# Plot a histogram of below average latitude
# on the second subplot axis. Set alpha to .6
# Set label to the string "Below"
# YOUR CODE HERE
ax[1].hist(blw_avg_lat,label='Below', alpha=0.6)
 
# Set the title for the second subplot axis
# to the string "Latitude"
# YOUR CODE HERE
 
ax[1].set_title("Latitude")
plt.legend()

# %% [markdown]
# **Interpret the above visualization. How does it relate to your client's claims?**

# %% [markdown]
# By analysing Longitude data, abaove average returants are siightly more in East.
# By analysing Lantitude Data, I can see clearly the above average resturants are in Noth

# %% [markdown]
# ## Find the most common zipcode for above average restaurants
#
# In the cell below, loop over the restaurants in the above average dataset and count the frequency of the restaurants zipcode.

# %%
# Create an empty dictionary
# This dictionary will hold the counts
# for each zipcode
abv_avg_zip_cnts = {} # YOUR CODE HERE
 
# Loop over the above average dataset
# YOUR CODE HERE
 
for i in isolate_values(isolate_values(above_average,'location'),'zip_code'):
     
    # Isolate the restaurant's zipcode 
    # YOUR CODE HERE
    if i in abv_avg_zip_cnts:
        abv_avg_zip_cnts[i]+=1
    else:
        abv_avg_zip_cnts[i]=1
     
     
    # Check if the zipcode is a key in the dictionary
    # YOUR CODE HERE
      
        
        # Add one to the zipcode's value
        # YOUR CODE HERE
    
    # If the zipcode is not a key
    # add it to the dictionary with a value of 1
    # YOUR CODE HERE

# %% [markdown]
# Run the next cell unchanged to test your work!
# > If the below cell runs without throwing an error, your code is likely correct!

# %%
assert type(abv_avg_zip_cnts) == dict
assert len(abv_avg_zip_cnts) == 104 or len(abv_avg_zip_cnts) == 103
assert '10012' in abv_avg_zip_cnts

# %% [markdown]
# Now loop over the `abv_avg_zip_cnts` dictionary and find the zipcode with the largest count.
#
# For this question, there are multiple ways to find the solution. Comments have not been provided.

# %%
# Your code here
zip_max = ' '
zip_freq = 0
for zip in abv_avg_zip_cnts:
    if abv_avg_zip_cnts[zip] > zip_freq:
        zip_freq = abv_avg_zip_cnts[zip]
        zip_max  = zip
print(zip_freq)
print(zip_max)
# Out:
# 13
# 10014

# %% [markdown]
# **Interpret the results. How does the most frequent zipcode relate to your client's claims?**

# %% [markdown]
# The customer belive that the 10012 zipcode in New York City is the best place to open a restaurant. They wish to open a restaurant in close proximity to other highly rated restaurants, and they believe 10012 has the most in NYC. However the highly rated returants are in 10014

# %% [markdown]
# ## Compile your findings into a report
#
# You have address all of your client's claims! In the cell below, describe the findings of your analysis.

# %% [markdown]
# 1.There are 40 restaurants with for 5 rating. There are 260 restaurants for 4.5 ratings. There are 440 restaurants for 4 ratings. There are 190 restaurants for 3.5 rating. The client will be in the market with these restaurants.
#
# 2.There are 306 restaurants that are in above average l review.
# 3. $$ is the most common price
# 4. By analysing Longitude data, above average restaurants are slightly more in East (compared to below avarage ).
# By analysing Latitude Data, I can see above average restaurants are also in North.
# However , by analysing overall Longitude data and Latitude Data, most above average restraints are located in South west. My recommendation would be to locate the resturant in South.
# 5.As per the analysis close proximity to other highly rated restaurants are in 10014 in NYC

# %% [markdown]
# # Summary
#
# Well done! As you can see, manipulating nested data stuctures can be a challenging task. Pulling information from json objects requires a thoughtful inspection of how the data is organized, and code that allows you to avoid repetition.
